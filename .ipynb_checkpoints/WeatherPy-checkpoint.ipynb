# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 610

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Perform a weather check on each city using a series of successive API calls.

# make the base url where the query needs to go
base_url = "http://api.openweathermap.org/data/2.5/weather?appid="

# Create dataframe to be added to in for loop
weatherDF = pd.DataFrame()
weatherDF["City"] = ""
weatherDF["Cloudiness"] = ""
weatherDF["Country"] = ""
weatherDF["Date"] = "" 
weatherDF["Humidity"] = ""
weatherDF["Lat"] = ""
weatherDF["Lng"] = ""
weatherDF["Max Temp"] = ""
weatherDF["Wind Speed"] = ""


# Include a print log of each city as it'sbeing processed (with the city number and city name).

# Print out the beginning of the log
print("Beginning Data Retrieval")
print("----------------------------")

# Loop through all of the cities within the cities 
for x in np.arange(len(cities)):

    # Print the recording of the current record with the city
    print(f"Processing record {x} | {cities[x]}")
    
    # start try/except to compensate for failed retrieval
    try:
        
        # Request the current wheather statistics from built URL of the current city in JSON form
        currentWeather = requests.get(f"{base_url}{api_key}&q={cities[x]}&units=imperial").json()
        
        # Place all of the variables into the created dataframe
        weatherDF.loc[x, "City"] = currentWeather["name"]
        weatherDF.loc[x, "Cloudiness"] = currentWeather["clouds"]["all"]            
        weatherDF.loc[x, "Country"] = currentWeather["sys"]["country"]
        weatherDF.loc[x, "Date"] = currentWeather["dt"]
        weatherDF.loc[x, "Humidity"] = currentWeather["main"]["humidity"]
        weatherDF.loc[x, "Lat"] = currentWeather["coord"]["lat"]
        weatherDF.loc[x, "Lng"] = currentWeather["coord"]["lon"]
        weatherDF.loc[x, "Max Temp"] = currentWeather["main"]["temp_max"]
        weatherDF.loc[x, "Wind Speed"] = currentWeather["wind"]["speed"]
    
    # If previous block did not work display error message
    except (KeyError, IndexError):
        print("City not found. Skipping...")

# Print end of data message
print("----------------------------")
print("Data Retrieval Complete")
print("----------------------------")

# Drop bad data
cleanWeather = weatherDF.dropna()
# Out:
# Beginning Data Retrieval
# ----------------------------
# Processing record 0 | saint-augustin
# Processing record 1 | fortuna
# Processing record 2 | hobart
# Processing record 3 | baracoa
# Processing record 4 | pinega
# Processing record 5 | buqayq
# City not found. Skipping...
# Processing record 6 | luderitz
# Processing record 7 | college
# Processing record 8 | salamiyah
# Processing record 9 | middelburg
# Processing record 10 | mataura
# Processing record 11 | noyabrsk
# Processing record 12 | new norfolk
# Processing record 13 | ahipara
# Processing record 14 | east london
# Processing record 15 | thompson
# Processing record 16 | blagoyevo
# Processing record 17 | krutinka
# Processing record 18 | atuona
# Processing record 19 | naze
# Processing record 20 | bluff
# Processing record 21 | taolanaro
# City not found. Skipping...
# Processing record 22 | hamilton
# Processing record 23 | yellowknife
# Processing record 24 | valadares
# Processing record 25 | batemans bay
# Processing record 26 | vaini
# Processing record 27 | prabumulih
# Processing record 28 | jamestown
# Processing record 29 | pevek
# Processing record 30 | albany
# Processing record 31 | saint anthony
# Processing record 32 | qaanaaq
# Processing record 33 | joshimath
# Processing record 34 | rikitea
# Processing record 35 | monrovia
# Processing record 36 | weligama
# Processing record 37 | belushya guba
# City not found. Skipping...
# Processing record 38 | hasaki
# Processing record 39 | ilulissat
# Processing record 40 | talcahuano
# Processing record 41 | torbay
# Processing record 42 | chapais
# Processing record 43 | oga
# Processing record 44 | cherskiy
# Processing record 45 | tiksi
# Processing record 46 | mys shmidta
# City not found. Skipping...
# Processing record 47 | ushuaia
# Processing record 48 | esperance
# Processing record 49 | port alfred
# Processing record 50 | punta arenas
# Processing record 51 | arraial do cabo
# Processing record 52 | constitucion
# Processing record 53 | sinnamary
# Processing record 54 | upernavik
# Processing record 55 | narsaq
# Processing record 56 | serdobsk
# Processing record 57 | georgetown
# Processing record 58 | sakaiminato
# Processing record 59 | bubaque
# Processing record 60 | liverpool
# Processing record 61 | nara
# Processing record 62 | nchelenge
# Processing record 63 | mar del plata
# Processing record 64 | qaqortoq
# Processing record 65 | victoria
# Processing record 66 | hermanus
# Processing record 67 | ballina
# Processing record 68 | puerto ayora
# Processing record 69 | vao
# Processing record 70 | sur
# Processing record 71 | busselton
# Processing record 72 | teguldet
# Processing record 73 | hilo
# Processing record 74 | puerto madero
# Processing record 75 | portland
# Processing record 76 | jiehu
# Processing record 77 | merauke
# Processing record 78 | bathsheba
# Processing record 79 | honningsvag
# Processing record 80 | fereydun kenar
# Processing record 81 | hami
# Processing record 82 | pisco
# Processing record 83 | tuktoyaktuk
# Processing record 84 | ewo
# Processing record 85 | lodja
# Processing record 86 | illoqqortoormiut
# City not found. Skipping...
# Processing record 87 | necochea
# Processing record 88 | hirado
# Processing record 89 | charters towers
# Processing record 90 | rundu
# Processing record 91 | chokurdakh
# Processing record 92 | ayan
# Processing record 93 | puebloviejo
# Processing record 94 | nogliki
# Processing record 95 | dikson
# Processing record 96 | saleaula
# City not found. Skipping...
# Processing record 97 | severo-kurilsk
# Processing record 98 | souillac
# Processing record 99 | makushino
# Processing record 100 | provideniya
# Processing record 101 | tumannyy
# City not found. Skipping...
# Processing record 102 | cayenne
# Processing record 103 | atyrau
# Processing record 104 | butaritari
# Processing record 105 | mrirt
# City not found. Skipping...
# Processing record 106 | riviere-au-renard
# Processing record 107 | kavieng
# Processing record 108 | neryungri
# Processing record 109 | kaitangata
# Processing record 110 | vaitupu
# City not found. Skipping...
# Processing record 111 | andevoranto
# City not found. Skipping...
# Processing record 112 | anju
# Processing record 113 | shirokiy
# Processing record 114 | ostrovnoy
# Processing record 115 | ucluelet
# Processing record 116 | sug-aksy
# City not found. Skipping...
# Processing record 117 | rathkeale
# Processing record 118 | ban nahin
# Processing record 119 | clyde river
# Processing record 120 | cidreira
# Processing record 121 | galesong
# Processing record 122 | mount gambier
# Processing record 123 | niquelandia
# Processing record 124 | cairns
# Processing record 125 | lebu
# Processing record 126 | amderma
# City not found. Skipping...
# Processing record 127 | chernyshevskiy
# Processing record 128 | saint-philippe
# Processing record 129 | kutum
# Processing record 130 | pierre
# Processing record 131 | san quintin
# Processing record 132 | port hardy
# Processing record 133 | ponta do sol
# Processing record 134 | leh
# Processing record 135 | muros
# Processing record 136 | nikolskoye
# Processing record 137 | khatanga
# Processing record 138 | cape town
# Processing record 139 | tasiilaq
# Processing record 140 | islamkot
# Processing record 141 | kodinsk
# Processing record 142 | nkhotakota
# Processing record 143 | rabat
# Processing record 144 | pedasi
# Processing record 145 | barentsburg
# City not found. Skipping...
# Processing record 146 | tanout
# Processing record 147 | ambilobe
# Processing record 148 | kapaa
# Processing record 149 | kruisfontein
# Processing record 150 | celestun
# Processing record 151 | ribeira grande
# Processing record 152 | tsihombe
# City not found. Skipping...
# Processing record 153 | hithadhoo
# Processing record 154 | tuatapere
# Processing record 155 | gwanda
# Processing record 156 | siderno
# Processing record 157 | kintampo
# Processing record 158 | port elizabeth
# Processing record 159 | anshun
# Processing record 160 | hofn
# Processing record 161 | castro
# Processing record 162 | salug
# Processing record 163 | manaia
# Processing record 164 | mount isa
# Processing record 165 | asyut
# Processing record 166 | sitka
# Processing record 167 | half moon bay
# Processing record 168 | eldikan
# City not found. Skipping...
# Processing record 169 | cape elizabeth
# City not found. Skipping...
# Processing record 170 | nemuro
# Processing record 171 | costa rica
# Processing record 172 | azle
# Processing record 173 | palmer
# Processing record 174 | leningradskiy
# Processing record 175 | rio branco
# Processing record 176 | tripoli
# Processing record 177 | seoul
# Processing record 178 | sembakung
# Processing record 179 | talnakh
# Processing record 180 | meinung
# City not found. Skipping...
# Processing record 181 | vardo
# Processing record 182 | beoumi
# Processing record 183 | valkeakoski
# Processing record 184 | dodge city
# Processing record 185 | haverfordwest
# Processing record 186 | broome
# Processing record 187 | mendahara
# City not found. Skipping...
# Processing record 188 | colac
# Processing record 189 | yamada
# Processing record 190 | arlit
# Processing record 191 | marrakesh
# Processing record 192 | barrow
# Processing record 193 | state college
# Processing record 194 | manado
# Processing record 195 | airai
# Processing record 196 | nizhneyansk
# City not found. Skipping...
# Processing record 197 | flinders
# Processing record 198 | vylgort
# City not found. Skipping...
# Processing record 199 | san patricio
# Processing record 200 | slyudyanka
# Processing record 201 | bambous virieux
# Processing record 202 | jinchang
# Processing record 203 | los llanos de aridane
# Processing record 204 | khonuu
# City not found. Skipping...
# Processing record 205 | sao joao da barra
# Processing record 206 | cabo san lucas
# Processing record 207 | katsuura
# Processing record 208 | ghanzi
# Processing record 209 | port-gentil
# Processing record 210 | bethel
# Processing record 211 | paamiut
# Processing record 212 | koshurnikovo
# Processing record 213 | kodiak
# Processing record 214 | salalah
# Processing record 215 | rafai
# Processing record 216 | abu zabad
# Processing record 217 | burica
# City not found. Skipping...
# Processing record 218 | honiara
# Processing record 219 | evensk
# Processing record 220 | hobyo
# Processing record 221 | hay river
# Processing record 222 | bridlington
# Processing record 223 | sorong
# Processing record 224 | richards bay
# Processing record 225 | conceicao do araguaia
# Processing record 226 | boddam
# Processing record 227 | faanui
# Processing record 228 | carnarvon
# Processing record 229 | chuy
# Processing record 230 | vanimo
# Processing record 231 | bayangol
# Processing record 232 | maragogi
# Processing record 233 | sosnovo
# Processing record 234 | ancud
# Processing record 235 | taoudenni
# Processing record 236 | avarua
# Processing record 237 | norsup
# Processing record 238 | puquio
# Processing record 239 | usinsk
# Processing record 240 | duluth
# Processing record 241 | marihatag
# Processing record 242 | kenora
# Processing record 243 | lorengau
# Processing record 244 | margate
# Processing record 245 | norman wells
# Processing record 246 | asfi
# City not found. Skipping...
# Processing record 247 | gangakher
# Processing record 248 | opuwo
# Processing record 249 | touros
# Processing record 250 | port hedland
# Processing record 251 | svetlogorsk
# Processing record 252 | riyadh
# Processing record 253 | ponta delgada
# Processing record 254 | gawler
# Processing record 255 | vanavara
# Processing record 256 | belmonte
# Processing record 257 | korla
# City not found. Skipping...
# Processing record 258 | zhigansk
# Processing record 259 | kahului
# Processing record 260 | senanga
# Processing record 261 | neiafu
# Processing record 262 | alofi
# Processing record 263 | husavik
# Processing record 264 | rantepao
# Processing record 265 | nouadhibou
# Processing record 266 | linxia
# Processing record 267 | iralaya
# Processing record 268 | iqaluit
# Processing record 269 | coquimbo
# Processing record 270 | la ronge
# Processing record 271 | dayong
# Processing record 272 | adrar
# Processing record 273 | bengkulu
# City not found. Skipping...
# Processing record 274 | sinegorye
# Processing record 275 | sentyabrskiy
# City not found. Skipping...
# Processing record 276 | pangkalanbuun
# Processing record 277 | sao jose da coroa grande
# Processing record 278 | yomitan
# City not found. Skipping...
# Processing record 279 | sao bento do sul
# Processing record 280 | yuzhnyy
# Processing record 281 | lubango
# Processing record 282 | imperia
# Processing record 283 | marcona
# City not found. Skipping...
# Processing record 284 | coihaique
# Processing record 285 | kavaratti
# Processing record 286 | tignere
# Processing record 287 | saskylakh
# Processing record 288 | olafsvik
# City not found. Skipping...
# Processing record 289 | alice springs
# Processing record 290 | xingtai
# Processing record 291 | simplicio mendes
# Processing record 292 | kisangani
# Processing record 293 | gazanjyk
# Processing record 294 | pandan
# Processing record 295 | lavrentiya
# Processing record 296 | kelso
# Processing record 297 | nouakchott
# Processing record 298 | plettenberg bay
# Processing record 299 | cachoeira do sul
# Processing record 300 | aquidauana
# Processing record 301 | uyuni
# Processing record 302 | bredasdorp
# Processing record 303 | mackay
# Processing record 304 | los arcos
# Processing record 305 | chara
# Processing record 306 | akdepe
# Processing record 307 | salta
# Processing record 308 | saldanha
# Processing record 309 | port augusta
# Processing record 310 | manggar
# Processing record 311 | sinnar
# Processing record 312 | krasnoborsk
# Processing record 313 | dalbandin
# Processing record 314 | benjamin constant
# Processing record 315 | rawson
# Processing record 316 | xinye
# Processing record 317 | khash
# Processing record 318 | huancavelica
# Processing record 319 | phan rang
# City not found. Skipping...
# Processing record 320 | walvis bay
# Processing record 321 | koulikoro
# Processing record 322 | ijaki
# City not found. Skipping...
# Processing record 323 | shimoda
# Processing record 324 | northam
# Processing record 325 | saint-francois
# Processing record 326 | geresk
# City not found. Skipping...
# Processing record 327 | llata
# Processing record 328 | ixtapa
# Processing record 329 | san cristobal
# Processing record 330 | tabuk
# Processing record 331 | nanortalik
# Processing record 332 | tevaitoa
# Processing record 333 | acajutla
# Processing record 334 | natal
# Processing record 335 | sept-iles
# Processing record 336 | guayaramerin
# Processing record 337 | sobolevo
# Processing record 338 | umm lajj
# Processing record 339 | tahe
# Processing record 340 | eskasem
# City not found. Skipping...
# Processing record 341 | grindavik
# Processing record 342 | faya
# Processing record 343 | sackville
# Processing record 344 | kieta
# Processing record 345 | tilichiki
# Processing record 346 | san policarpo
# Processing record 347 | gisborne
# Processing record 348 | fuxin
# Processing record 349 | meulaboh
# Processing record 350 | salgueiro
# Processing record 351 | hovd
# Processing record 352 | muncar
# Processing record 353 | princeton
# Processing record 354 | cheuskiny
# City not found. Skipping...
# Processing record 355 | samusu
# City not found. Skipping...
# Processing record 356 | longyearbyen
# Processing record 357 | darnah
# Processing record 358 | kalmunai
# Processing record 359 | bonthe
# Processing record 360 | umm kaddadah
# Processing record 361 | watertown
# Processing record 362 | eyl
# Processing record 363 | henties bay
# Processing record 364 | lesnoy
# Processing record 365 | dauphin
# Processing record 366 | morondava
# Processing record 367 | attawapiskat
# City not found. Skipping...
# Processing record 368 | geraldton
# Processing record 369 | dunedin
# Processing record 370 | yar-sale
# Processing record 371 | shaoguan
# Processing record 372 | umzimvubu
# City not found. Skipping...
# Processing record 373 | namibe
# Processing record 374 | nizwa
# Processing record 375 | vaxjo
# City not found. Skipping...
# Processing record 376 | butajira
# Processing record 377 | tera
# Processing record 378 | vila franca do campo
# Processing record 379 | sarkand
# Processing record 380 | khon buri
# Processing record 381 | novopokrovka
# Processing record 382 | ushtobe
# Processing record 383 | berlevag
# Processing record 384 | red bank
# Processing record 385 | gravdal
# Processing record 386 | concordia
# Processing record 387 | bac lieu
# City not found. Skipping...
# Processing record 388 | sao filipe
# Processing record 389 | fukuma
# Processing record 390 | grand river south east
# City not found. Skipping...
# Processing record 391 | antofagasta
# Processing record 392 | tsaratanana
# Processing record 393 | sinjar
# Processing record 394 | chimore
# Processing record 395 | auriflama
# Processing record 396 | assai
# City not found. Skipping...
# Processing record 397 | soe
# Processing record 398 | coahuayana
# Processing record 399 | luxeuil-les-bains
# Processing record 400 | makakilo city
# Processing record 401 | dedougou
# Processing record 402 | causapscal
# Processing record 403 | petropavlovka
# Processing record 404 | aksu
# Processing record 405 | avera
# Processing record 406 | udachnyy
# Processing record 407 | villa vazquez
# City not found. Skipping...
# Processing record 408 | north bend
# Processing record 409 | shingu
# Processing record 410 | kastamonu
# Processing record 411 | saint george
# Processing record 412 | bilibino
# Processing record 413 | mersing
# Processing record 414 | lingao
# Processing record 415 | krasnoslobodsk
# Processing record 416 | shimizu
# Processing record 417 | burns lake
# Processing record 418 | huarmey
# Processing record 419 | mahebourg
# Processing record 420 | grinnell
# Processing record 421 | ontario
# Processing record 422 | fairbanks
# Processing record 423 | codrington
# Processing record 424 | waddan
# Processing record 425 | balkhash
# Processing record 426 | alappuzha
# City not found. Skipping...
# Processing record 427 | garoua
# Processing record 428 | nguiu
# City not found. Skipping...
# Processing record 429 | klaksvik
# Processing record 430 | zagan
# Processing record 431 | lalsot
# Processing record 432 | abu dhabi
# Processing record 433 | prescott
# Processing record 434 | saquena
# Processing record 435 | atasu
# Processing record 436 | dingle
# Processing record 437 | aklavik
# Processing record 438 | cozumel
# City not found. Skipping...
# Processing record 439 | puerto lempira
# Processing record 440 | darovskoy
# Processing record 441 | sterling
# Processing record 442 | banposh
# Processing record 443 | hirara
# Processing record 444 | kargala
# Processing record 445 | bargal
# City not found. Skipping...
# Processing record 446 | tsiroanomandidy
# Processing record 447 | aguimes
# Processing record 448 | ballarat
# Processing record 449 | saint-joseph
# Processing record 450 | acapulco
# Processing record 451 | prado
# Processing record 452 | baft
# Processing record 453 | wazzan
# City not found. Skipping...
# Processing record 454 | lagoa
# Processing record 455 | bata
# Processing record 456 | salinopolis
# Processing record 457 | sao paulo de olivenca
# Processing record 458 | grimshaw
# Processing record 459 | nioro
# Processing record 460 | fort nelson
# Processing record 461 | louisbourg
# City not found. Skipping...
# Processing record 462 | catamarca
# City not found. Skipping...
# Processing record 463 | tagusao
# Processing record 464 | komsomolskiy
# Processing record 465 | harper
# Processing record 466 | porto novo
# Processing record 467 | manokwari
# Processing record 468 | gondanglegi
# Processing record 469 | kayerkan
# Processing record 470 | valley city
# Processing record 471 | matagami
# Processing record 472 | farafangana
# Processing record 473 | lata
# Processing record 474 | jiddah
# City not found. Skipping...
# Processing record 475 | zile
# Processing record 476 | doha
# Processing record 477 | lamar
# Processing record 478 | cabedelo
# Processing record 479 | derzhavinsk
# Processing record 480 | padang
# Processing record 481 | paracuru
# Processing record 482 | vilyuysk
# Processing record 483 | fort madison
# Processing record 484 | port lincoln
# Processing record 485 | kaka
# Processing record 486 | sotouboua
# Processing record 487 | tocopilla
# Processing record 488 | pyshchug
# Processing record 489 | itacare
# Processing record 490 | mtimbira
# Processing record 491 | ano mera
# Processing record 492 | karkaralinsk
# City not found. Skipping...
# Processing record 493 | verkhniy lomov
# Processing record 494 | hambantota
# Processing record 495 | zyryanka
# Processing record 496 | pascagoula
# Processing record 497 | jiexiu
# Processing record 498 | mama
# Processing record 499 | tuggurt
# City not found. Skipping...
# Processing record 500 | rio gallegos
# Processing record 501 | venice
# Processing record 502 | puerto escondido
# Processing record 503 | alekseyevsk
# Processing record 504 | canala
# Processing record 505 | darhan
# Processing record 506 | hokitika
# Processing record 507 | yulara
# Processing record 508 | nenjiang
# Processing record 509 | kaeo
# Processing record 510 | mae sai
# Processing record 511 | solnechnyy
# Processing record 512 | miquelon
# Processing record 513 | calatayud
# Processing record 514 | mangrol
# Processing record 515 | abha
# Processing record 516 | truth or consequences
# Processing record 517 | knysna
# Processing record 518 | aqtobe
# Processing record 519 | hailar
# Processing record 520 | igrim
# Processing record 521 | dumas
# Processing record 522 | beohari
# Processing record 523 | mirnyy
# Processing record 524 | nabire
# Processing record 525 | agirish
# Processing record 526 | san lorenzo
# Processing record 527 | escarcega
# Processing record 528 | nea vissa
# Processing record 529 | inuvik
# Processing record 530 | camacha
# Processing record 531 | cockburn town
# Processing record 532 | paka
# Processing record 533 | roald
# Processing record 534 | qafsah
# City not found. Skipping...
# Processing record 535 | mayumba
# Processing record 536 | yanai
# Processing record 537 | marang
# City not found. Skipping...
# Processing record 538 | varghis
# Processing record 539 | taltal
# Processing record 540 | kjollefjord
# Processing record 541 | tibati
# Processing record 542 | mikhaylovka
# Processing record 543 | tura
# Processing record 544 | mehran
# Processing record 545 | mitu
# Processing record 546 | nagornyy
# City not found. Skipping...
# Processing record 547 | isla vista
# Processing record 548 | pahalgam
# Processing record 549 | skovorodino
# Processing record 550 | nelson bay
# Processing record 551 | ewa beach
# Processing record 552 | thunder bay
# Processing record 553 | eureka
# Processing record 554 | gisors
# Processing record 555 | ksenyevka
# City not found. Skipping...
# Processing record 556 | rio grande
# Processing record 557 | guaymas
# Processing record 558 | mezen
# Processing record 559 | ljubinje
# Processing record 560 | benguela
# Processing record 561 | vermillion
# Processing record 562 | pacific grove
# Processing record 563 | san ramon
# Processing record 564 | samarai
# Processing record 565 | tamiahua
# Processing record 566 | katobu
# Processing record 567 | maceio
# Processing record 568 | te anau
# Processing record 569 | salvador
# Processing record 570 | sao felix do xingu
# Processing record 571 | guane
# Processing record 572 | beauvais
# Processing record 573 | alghero
# Processing record 574 | thinadhoo
# Processing record 575 | tabiauea
# City not found. Skipping...
# Processing record 576 | rocha
# Processing record 577 | arkhipo-osipovka
# Processing record 578 | atar
# Processing record 579 | chumikan
# Processing record 580 | axim
# Processing record 581 | jand
# Processing record 582 | bur gabo
# City not found. Skipping...
# Processing record 583 | capreol
# Processing record 584 | bongandanga
# Processing record 585 | kudahuvadhoo
# Processing record 586 | parkes
# Processing record 587 | linchuan
# City not found. Skipping...
# Processing record 588 | palabuhanratu
# City not found. Skipping...
# Processing record 589 | banda aceh
# Processing record 590 | khor
# Processing record 591 | moerai
# Processing record 592 | imeni poliny osipenko
# Processing record 593 | goderich
# Processing record 594 | brownwood
# Processing record 595 | baykit
# Processing record 596 | ye
# City not found. Skipping...
# Processing record 597 | itapora
# Processing record 598 | wilmington island
# Processing record 599 | mao
# Processing record 600 | yanan
# City not found. Skipping...
# Processing record 601 | fergus falls
# Processing record 602 | boa vista
# Processing record 603 | seydisehir
# Processing record 604 | lommel
# Processing record 605 | isangel
# Processing record 606 | lompoc
# Processing record 607 | hunza
# City not found. Skipping...
# Processing record 608 | aktas
# City not found. Skipping...
# Processing record 609 | biloela
# Processing record 610 | kidal
# Processing record 611 | mason city
# Processing record 612 | sangar
# Processing record 613 | bokhan
# Processing record 614 | chapada dos guimaraes
# Processing record 615 | sumbawanga
# ----------------------------
# Data Retrieval Complete
# ----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#Export the city data into a .csv, keep index, keep header
cleanWeather.to_csv(output_data_file, index=True, header=True)

# %%
# read CSV

cleanWeather_csv = "output_data/cities.csv"

cleanWeather = pd.read_csv(cleanWeather_csv, encoding="utf-8")
cleanWeather.head()
# Out:
#    Unnamed: 0            City  Cloudiness Country        Date  Humidity  \
# 0           0  Saint-Augustin          20      CA  1564372702        83
# 1           1         Fortuna           0      ES  1564372702        83
# 2           2          Hobart          75      AU  1564372601        64
# 3           3         Baracoa          20      CU  1564372702        80
# 4           4          Pinega         100      RU  1564372702        85
#
#      Lat     Lng  Max Temp  Wind Speed
# 0  45.63  -73.98     75.99        2.24
# 1  38.18   -1.13     73.99        3.36
# 2 -42.88  147.33     48.20       14.99
# 3  20.35  -74.50     81.23        9.60
# 4  64.70   43.39     45.23        9.57

# %%
# Display the DataFrame
cleanWeather.count()
# Out:
# Unnamed: 0    552
# City          552
# Cloudiness    552
# Country       547
# Date          552
# Humidity      552
# Lat           552
# Lng           552
# Max Temp      552
# Wind Speed    552
# dtype: int64

# %%
# Display the DataFrame
cleanWeather.head()
# Out:
#    Unnamed: 0            City  Cloudiness Country        Date  Humidity  \
# 0           0  Saint-Augustin          20      CA  1564372702        83
# 1           1         Fortuna           0      ES  1564372702        83
# 2           2          Hobart          75      AU  1564372601        64
# 3           3         Baracoa          20      CU  1564372702        80
# 4           4          Pinega         100      RU  1564372702        85
#
#      Lat     Lng  Max Temp  Wind Speed
# 0  45.63  -73.98     75.99        2.24
# 1  38.18   -1.13     73.99        3.36
# 2 -42.88  147.33     48.20       14.99
# 3  20.35  -74.50     81.23        9.60
# 4  64.70   43.39     45.23        9.57

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Latitude vs. Temperature Plot

# Plot a scatter plot of latitude vs temperature with formatting
plt.scatter(cleanWeather["Lat"], cleanWeather["Max Temp"], color="blue",
           edgecolors = "k", s = 50)

# Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
plt.title(f"City Latitude vs. Max Temp - July 28, 2019")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid()

# Save the plotted figures as .pngs.
plt.savefig("output_data/lat_v_max_temp.png")

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Latitude vs. Humidity Plot

# Plot a scatter plot of latitude vs humidity with formatting
plt.scatter(cleanWeather["Lat"], cleanWeather["Humidity"],color="blue",
           edgecolors = "k", s = 20)

# Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
plt.title("City Latitude vs. Humidity  - July 28, 2019")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid()

# Save the plotted figures as .pngs.
plt.savefig("output_data/lat_v_humid.png")

# %%
# Latitude vs. Humidity Plot

# Plot a scatter plot of latitude vs humidity with formatting
plt.scatter(cleanWeather["Lat"], cleanWeather["Humidity"],color="blue",
           edgecolors = "k", s = 20)

# Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
plt.title("City Latitude vs. Humidity  - July 28, 2019")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.xlim(-60, 100)
plt.ylim(-10, 120)
plt.grid()

# Save the plotted figures as .pngs.
plt.savefig("output_data/lat_v_humid_outlier_removed.png")

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Latitude vs. Cloudiness Plot

# Plot a scatter plot of latitude vs cloudiness with formatting
plt.scatter(cleanWeather["Lat"], cleanWeather["Cloudiness"],color="blue",
           edgecolors = "k", s = 50)

# Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
plt.title("City Latitude vs. Cloudiness  - July 28, 2019")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid()

# Save the plotted figures as .pngs.
plt.savefig("output_data/lat_v_cloud.png")

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Latitude vs. Wind Speed Plot

# Plot a scatter plot of latitude vs wind speed with formatting
plt.scatter(cleanWeather["Lat"], cleanWeather["Wind Speed"],color="blue",
           edgecolors = "k", s = 50)

# Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
plt.title("City Latitude vs. Wind Speed  - July 28, 2019")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid()

# Save the plotted figures as .pngs.
plt.savefig("output_data/lat_v_wind.png")
